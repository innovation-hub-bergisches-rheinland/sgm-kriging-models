# %%
import numpy as np
import pandas as pd

filename = "test/data/Versuchsdaten_v01_complete.CSV"

file_pd = pd.read_csv(filename, sep=";", decimal='.')

file_pd.head(2)
# Out:
#    Id  cylinder_temperature  flow_temperature  holding_pressure  \
# 0   1            199.472782         19.857499               100
# 1   2            199.183943         19.845833               400
#
#    holding_pressure_time  locking_force  nozzle_touch_force  \
# 0                     10     494.171806           33.021293
# 1                      6      98.850945           32.884305
#
#    injection_volume_flow  opening_speed  closing_speed  ...  cooling_time  \
# 0               9.961404            225            300  ...     99.387001
# 1               9.961404            100            225  ...      9.716000
#
#    cycle_time  element_related_mass  max_volume_shrinkage  \
# 0  124.594666             31.122826             16.616695
# 1   33.241999             30.907356             16.818401
#
#    avg_volume_shrinkage  required_cooling_time  max_warpage  max_deformation  \
# 0             11.429642             767.539062     0.597446         1.105855
# ...

# %%
import pandas as pd

raw_data = pd.read_csv('test/data/Versuchsdaten_v01_complete.CSV', sep=';', decimal='.').to_dict('list')

raw_data
raw_data['cooling_time']
# Out:
# [99.38700104,
#  9.71600008,
#  99.47849846,
#  99.53350067,
#  9.601500034,
#  9.424999952,
#  99.47133382,
#  54.62849903,
#  99.74099922,
#  9.309000015,
#  9.314999819,
#  9.376499891,
#  54.55840073,
#  99.59649849,
#  9.512000084,
#  9.376999855,
#  99.73250008,
#  54.6239996,
#  99.41749954,
#  99.45149994,
#  9.625999928,
#  9.553999901,
#  9.546999931,
#  99.52149963,
#  99.18200111]
